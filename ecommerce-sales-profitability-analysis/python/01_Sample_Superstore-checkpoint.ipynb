# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## install xlrd to import xls type files

# %%
# %pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\arshi\appdata\local\programs\python\python313\lib\site-packages (2.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: C:\Users\arshi\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## to see what files we have in our folder

# %%
import os

folder = r"C:\Users\arshi\OneDrive\Desktop\New Project"
print(os.listdir(folder))
# Out:
# ['.ipynb_checkpoints', '01_Sample_Superstore.ipynb', '02_Data cleaning.ipynb', '03_Epxploratory_Data_Analysis.ipynb', 'EDA Findings.txt', 'Orders_Clean.csv', 'Orders_Clean_UTF8.csv', 'Power_BI_Dashboard.pbix', 'Project_description.txt', 'sample_superstore.xls', 'Workbench']

# %%
import pandas as pd

file_path = r"C:\Users\arshi\OneDrive\Desktop\New Project\sample_superstore.xls"

Orders = pd.read_excel(file_path, sheet_name="Orders")
People = pd.read_excel(file_path, sheet_name="People")
Returns = pd.read_excel(file_path, sheet_name="Returns")

# %%
Orders.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03 2023-01-07  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
#
#    Customer Name      Segment Country/Region        City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States     Houston  ...       77095
# 1  Phillina Ober  Home Office  United States  Naperville  ...       60540
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  OFF-PA-10000174  Office Supplies        Paper
# 1  Central  OFF-BI-10004094  Office Supplies      Binders
#
#                                         Product Name   Sales  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  16.448         2
# 1         GBC Standard Plastic Binding Systems Combs   3.540         2
#
#    Discount  Profit
# 0       0.2  5.5512
# 1       0.8 -5.4870
#
# [2 rows x 21 columns]

# %%
Orders.sample(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3232    3233  US-2024-101154 2024-09-18 2024-09-21     First Class
# 907      908  US-2023-156244 2023-08-12 2023-08-16  Standard Class
# 7748    7749  US-2026-132297 2026-05-27 2026-06-02  Standard Class
# 6650    6651  US-2025-146325 2025-12-14 2025-12-17     First Class
# 585      586  US-2023-161305 2023-06-06 2023-06-12  Standard Class
# 6916    6917  CA-2026-115238 2026-01-21 2026-01-24  Standard Class
# 338      339  US-2023-165806 2023-04-07 2023-04-07        Same Day
# 4730    4731  US-2025-145247 2025-05-05 2025-05-07     First Class
# 3291    3292  US-2024-113131 2024-09-24 2024-09-24        Same Day
# 7899    7900  US-2026-169901 2026-06-15 2026-06-19  Standard Class
#
#      Customer ID      Customer Name      Segment Country/Region  \
# 3232    CM-12190   Charlotte Melton     Consumer  United States
# 907     DH-13675      Duane Huffman  Home Office  United States
# 7748    DW-13480      Dianna Wilson  Home Office  United States
# 6650    DS-13180        David Smith    Corporate  United States
# 585     SB-20170         Sarah Bern     Consumer  United States
# 6916    JW-15220          Jane Waco    Corporate         Canada
# 338     VM-21685    Valerie Mitchum  Home Office  United States
# 4730    ND-18370  Natalie DeCherney     Consumer  United States
# 3291    MB-17305    Maria Bertelson     Consumer  United States
# 7899    CC-12550      Clay Cheatham     Consumer  United States
#
#                City  ... Postal Code   Region       Product ID  \
# 3232      San Diego  ...       92105     West  OFF-ST-10004186
# 907           Miami  ...       33180    South  OFF-LA-10000443
# 7748     Louisville  ...       40214    South  TEC-PH-10002834
# 6650      San Diego  ...       92037     West  FUR-CH-10001146
# 585         Chicago  ...       60623  Central  OFF-BI-10002794
# 6916        Toronto  ...         M7A     East  FUR-FU-10002960
# 338        Marietta  ...       30062    South  OFF-PA-10003441
# 4730     Louisville  ...       40214    South  OFF-PA-10003641
# 3291       Columbus  ...       43229     East  OFF-AR-10003504
# 7899  San Francisco  ...       94122     West  TEC-PH-10002293
#
#              Category Sub-Category  \
# 3232  Office Supplies      Storage
# 907   Office Supplies       Labels
# 7748       Technology       Phones
# 6650        Furniture       Chairs
# 585   Office Supplies      Binders
# 6916        Furniture  Furnishings
# 338   Office Supplies        Paper
# 4730  Office Supplies        Paper
# 3291  Office Supplies          Art
# 7899       Technology       Phones
#
#                                            Product Name    Sales  Quantity  \
# 3232  Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x...  443.920         4
# 907                                           Avery 501    2.952         1
# 7748                                     Google Nexus 5  539.970         3
# 6650                           Global Task Chair, Black   81.424         2
# 585   Avery Trapezoid Ring Binder, 3" Capacity, Blac...   24.588         3
# 6916         Eldon 200 Class Desk Accessories, Burgundy   31.400         5
# 338                                           Xerox 226   58.320         9
# 4730                                         Xerox 1909   79.140         3
# 3291                                         Newell 347   17.120         5
# 7899  Anker 36W 4-Port USB Wall Charger Travel Power...   47.976         3
#
#       Discount    Profit
# 3232       0.0    8.8784
# 907        0.2    0.9963
# 7748       0.0  134.9925
# 6650       0.2   -9.1602
# 585        0.8  -38.1114
# 6916       0.0   13.1900
# 338        0.0   27.9936
# 4730       0.0   36.4044
# 3291       0.2    1.9260
# 7899       0.2    4.7976
#
# [10 rows x 21 columns]

# %%
Orders.info
# Out:
# <bound method DataFrame.info of        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2023-103800 2023-01-03 2023-01-07  Standard Class
# 1           2  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 2           3  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 3           4  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 4           5  US-2023-141817 2023-01-05 2023-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10190   10191  US-2026-115427 2026-12-30 2027-01-03  Standard Class
# 10191   10192  US-2026-156720 2026-12-30 2027-01-03  Standard Class
# 10192   10193  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10193   10194  CA-2026-143500 2026-12-30 2027-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# 1        PO-19195      Phillina Ober  Home Office  United States
# 2        PO-19195      Phillina Ober  Home Office  United States
# 3        PO-19195      Phillina Ober  Home Office  United States
# 4        MB-18085         Mick Brown     Consumer  United States
# ...           ...                ...          ...            ...
# 10189    PO-18865  Patrick O'Donnell     Consumer  United States
# 10190    EB-13975         Erica Bern    Corporate  United States
# 10191    JM-15580      Jill Matthias     Consumer  United States
# 10192    PO-18865  Patrick O'Donnell     Consumer  United States
# 10193    HO-15230        Harry Olson     Consumer         Canada
#
#                 City  ... Postal Code   Region       Product ID  \
# 0            Houston  ...       77095  Central  OFF-PA-10000174
# 1         Naperville  ...       60540  Central  OFF-BI-10004094
# 2         Naperville  ...       60540  Central  OFF-LA-10003223
# 3         Naperville  ...       60540  Central  OFF-ST-10002743
# 4       Philadelphia  ...       19143     East  OFF-AR-10003478
# ...              ...  ...         ...      ...              ...
# 10189  New York City  ...       10009     East  OFF-BI-10003684
# 10190      Fairfield  ...       94533     West  OFF-BI-10004632
# 10191       Loveland  ...       80538     West  OFF-FA-10003472
# 10192  New York City  ...       10009     East  TEC-PH-10004774
# 10193  Charlottetown  ...         C0A     East  OFF-BI-10004040
#
#               Category Sub-Category  \
# 0      Office Supplies        Paper
# 1      Office Supplies      Binders
# 2      Office Supplies       Labels
# 3      Office Supplies      Storage
# 4      Office Supplies          Art
# ...                ...          ...
# 10189  Office Supplies      Binders
# 10190  Office Supplies      Binders
# 10191  Office Supplies    Fasteners
# 10192       Technology       Phones
# 10193  Office Supplies      Binders
#
#                                             Product Name    Sales  Quantity  \
# 0      Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 1             GBC Standard Plastic Binding Systems Combs    3.540         2
# 2                                              Avery 508   11.784         3
# 3                          SAFCO Boltless Steel Shelving  272.736         3
# 4      Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
# ...                                                  ...      ...       ...
# 10189               Wilson Jones Legal Size Ring Binders   52.776         3
# 10190                                 GBC Binding covers   20.720         2
# 10191                                Bagged Rubber Bands    3.024         3
# 10192                          Gear Head AU3700S Headset   90.930         7
# 10193                        Wilson Jones Impact Binders    3.024         3
#
#        Discount   Profit
# 0           0.2   5.5512
# 1           0.8  -5.4870
# 2           0.2   4.2717
# 3           0.2 -64.7748
# 4           0.2   4.8840
# ...         ...      ...
# 10189       0.2  19.7910
# 10190       0.2   6.4750
# 10191       0.2  -0.6048
# 10192       0.0   2.7279
# 10193       0.2  -0.6048
#
# [10194 rows x 21 columns]>

# %%
Orders.describe
# Out:
# <bound method NDFrame.describe of        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2023-103800 2023-01-03 2023-01-07  Standard Class
# 1           2  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 2           3  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 3           4  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 4           5  US-2023-141817 2023-01-05 2023-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10190   10191  US-2026-115427 2026-12-30 2027-01-03  Standard Class
# 10191   10192  US-2026-156720 2026-12-30 2027-01-03  Standard Class
# 10192   10193  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10193   10194  CA-2026-143500 2026-12-30 2027-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# 1        PO-19195      Phillina Ober  Home Office  United States
# 2        PO-19195      Phillina Ober  Home Office  United States
# 3        PO-19195      Phillina Ober  Home Office  United States
# 4        MB-18085         Mick Brown     Consumer  United States
# ...           ...                ...          ...            ...
# 10189    PO-18865  Patrick O'Donnell     Consumer  United States
# 10190    EB-13975         Erica Bern    Corporate  United States
# 10191    JM-15580      Jill Matthias     Consumer  United States
# 10192    PO-18865  Patrick O'Donnell     Consumer  United States
# 10193    HO-15230        Harry Olson     Consumer         Canada
#
#                 City  ... Postal Code   Region       Product ID  \
# 0            Houston  ...       77095  Central  OFF-PA-10000174
# 1         Naperville  ...       60540  Central  OFF-BI-10004094
# 2         Naperville  ...       60540  Central  OFF-LA-10003223
# 3         Naperville  ...       60540  Central  OFF-ST-10002743
# 4       Philadelphia  ...       19143     East  OFF-AR-10003478
# ...              ...  ...         ...      ...              ...
# 10189  New York City  ...       10009     East  OFF-BI-10003684
# 10190      Fairfield  ...       94533     West  OFF-BI-10004632
# 10191       Loveland  ...       80538     West  OFF-FA-10003472
# 10192  New York City  ...       10009     East  TEC-PH-10004774
# 10193  Charlottetown  ...         C0A     East  OFF-BI-10004040
#
#               Category Sub-Category  \
# 0      Office Supplies        Paper
# 1      Office Supplies      Binders
# 2      Office Supplies       Labels
# 3      Office Supplies      Storage
# 4      Office Supplies          Art
# ...                ...          ...
# 10189  Office Supplies      Binders
# 10190  Office Supplies      Binders
# 10191  Office Supplies    Fasteners
# 10192       Technology       Phones
# 10193  Office Supplies      Binders
#
#                                             Product Name    Sales  Quantity  \
# 0      Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 1             GBC Standard Plastic Binding Systems Combs    3.540         2
# 2                                              Avery 508   11.784         3
# 3                          SAFCO Boltless Steel Shelving  272.736         3
# 4      Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
# ...                                                  ...      ...       ...
# 10189               Wilson Jones Legal Size Ring Binders   52.776         3
# 10190                                 GBC Binding covers   20.720         2
# 10191                                Bagged Rubber Bands    3.024         3
# 10192                          Gear Head AU3700S Headset   90.930         7
# 10193                        Wilson Jones Impact Binders    3.024         3
#
#        Discount   Profit
# 0           0.2   5.5512
# 1           0.8  -5.4870
# 2           0.2   4.2717
# 3           0.2 -64.7748
# 4           0.2   4.8840
# ...         ...      ...
# 10189       0.2  19.7910
# 10190       0.2   6.4750
# 10191       0.2  -0.6048
# 10192       0.0   2.7279
# 10193       0.2  -0.6048
#
# [10194 rows x 21 columns]>

# %% [markdown]
# ## checking for null values

# %%
import numpy as np

# %%
Orders.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %% [markdown]
# ## Checking for Duplicate records

# %%
Orders.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## checking for unique values

# %%
Orders.nunique()
# Out:
# Row ID            10194
# Order ID           5111
# Order Date         1242
# Ship Date          1338
# Ship Mode             4
# Customer ID         804
# Customer Name       800
# Segment               3
# Country/Region        2
# City                542
# State/Province       59
# Postal Code         654
# Region                4
# Product ID         1862
# Category              3
# Sub-Category         17
# Product Name       1849
# Sales              6161
# Quantity             14
# Discount             12
# Profit             7597
# dtype: int64

# %%
Orders.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State/Province            object
# Postal Code               object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %% [markdown]
# ## Which product generated the highest total sales?

# %%
Orders.groupby("Product Name")["Sales"].sum().sort_values(ascending=False)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
#                                                                                  ...
# Avery Hi-Liter Pen Style Six-Color Fluorescent Set                                 7.700
# Grip Seal Envelopes                                                                7.072
# Xerox 20                                                                           6.480
# Avery 5                                                                            5.760
# Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac                   1.624
# Name: Sales, Length: 1849, dtype: float64

# %% [markdown]
# ## Which state generated the highest total profit?

# %%
Top_profit_states=Orders.groupby("State/Province")["Profit"].sum().sort_values(ascending=False)
Top_profit_states.head(5)
# Out:
# State/Province
# California    76381.3871
# New York      74038.5486
# Washington    33402.6517
# Michigan      24463.1876
# Virginia      18597.9504
# Name: Profit, dtype: float64
